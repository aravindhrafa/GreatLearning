# %%
import pandas as pd
import numpy as np
import tarfile
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
ratings1= pd.read_csv("ratings_Electronics.csv",usecols = [0,1,2],names = ['userId','productId','ratings']) # Calling the CSV file 
ratings1
# Out:
#                  userId   productId  ratings
# 0         AKM1MP6P0OYPR  0132793040      5.0
# 1        A2CX7LUOHB2NDG  0321732944      5.0
# 2        A2NWSAGRHCP8N5  0439886341      1.0
# 3        A2WNBOD3WNDNKT  0439886341      3.0
# 4        A1GI0U4ZRJA8WN  0439886341      1.0
# 5        A1QGNMC6O1VW39  0511189877      5.0
# 6        A3J3BRHTDRFJ2G  0511189877      2.0
# 7        A2TY0BTJOTENPG  0511189877      5.0
# 8        A34ATBPOK6HCHY  0511189877      5.0
# 9         A89DO69P0XZ27  0511189877      5.0
# 10        AZYNQZ94U6VDB  0511189877      5.0
# 11       A1DA3W4GTFXP6O  0528881469      5.0
# 12       A29LPQQDG7LD5J  0528881469      1.0
# 13        AO94DHGC771SJ  0528881469      5.0
# 14        AMO214LNFCEI4  0528881469      1.0
# 15       A28B1G1MSJ6OO1  0528881469      4.0
# 16       A3N7T0DY83Y4IG  0528881469      3.0
# 17       A1H8PY3QHMQQA0  0528881469      2.0
# 18        A2CPBQ5W4OGBX  0528881469      2.0
# 19       A265MKAR2WEH3Y  0528881469      4.0
# ...

# %%
ratings1.head(5)
# Out:
#            userId   productId  ratings
# 0   AKM1MP6P0OYPR  0132793040      5.0
# 1  A2CX7LUOHB2NDG  0321732944      5.0
# 2  A2NWSAGRHCP8N5  0439886341      1.0
# 3  A2WNBOD3WNDNKT  0439886341      3.0
# 4  A1GI0U4ZRJA8WN  0439886341      1.0

# %%
ratings1.columns
# Out:
# Index(['userId', 'productId', 'ratings'], dtype='object')

# %%
ratings1.shape
# Out:
# (7824482, 3)

# %%
ratings1.isnull().sum()
# Out:
# userId       0
# productId    0
# ratings      0
# dtype: int64

# %%
ratings1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7824482 entries, 0 to 7824481
# Data columns (total 3 columns):
# userId       object
# productId    object
# ratings      float64
# dtypes: float64(1), object(2)
# memory usage: 179.1+ MB

# %%
ratings1.dtypes
# Out:
# userId        object
# productId     object
# ratings      float64
# dtype: object

# %%
ratings1["userId"]= ratings1.userId.astype('category')
ratings1["productId"]= ratings1.productId.astype('category')

# %%
ratings1.dtypes
# Out:
# userId       category
# productId    category
# ratings       float64
# dtype: object

# %%
ratings1.describe()
# Out:
#             ratings
# count  7.824482e+06
# mean   4.012337e+00
# std    1.380910e+00
# min    1.000000e+00
# 25%    3.000000e+00
# 50%    5.000000e+00
# 75%    5.000000e+00
# max    5.000000e+00

# %%
ratings1.describe().T
# Out:
#              count      mean      std  min  25%  50%  75%  max
# ratings  7824482.0  4.012337  1.38091  1.0  3.0  5.0  5.0  5.0

# %%
sns.pairplot(ratings1, size=7,aspect=0.5 , diag_kind='kde')
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [raw]
# 1)From the above plot, ratings for products having 5.0 are found high
# when compared to other ratings
# 2)The ratings counts decreases progressively as we go down on the ratings
#      5.0 > 4.0 > 1.0 > 3.0 > 2.0

# %%
#Rating label distribution 

ratings1['ratings'].value_counts()
# Out:
# 5.0    4347541
# 4.0    1485781
# 1.0     901765
# 3.0     633073
# 2.0     456322
# Name: ratings, dtype: int64

# %%
x1 = ratings1.loc[ratings1.ratings=='5']
x2 = ratings1.loc[ratings1.ratings=='4']
x3 = ratings1.loc[ratings1.ratings=='3']
x4 = ratings1.loc[ratings1.ratings=='2']
x5 = ratings1.loc[ratings1.ratings=='1']

kwargs = dict(alpha=0.5,bins= 100)
plt.hist(x1,**kwargs,color='r',label = "Excellent")
plt.hist(x2,**kwargs,color='g',label = "Good")
plt.hist(x3,**kwargs,color='b',label = "Medium")
plt.hist(x4,**kwargs,color='y',label = "Not Good")
plt.hist(x5,**kwargs,color='b',label = "Worse")

plt.gca().set(title = 'Amazon Product Distribution',xlabel = 'Rating for the products')
# Get current axis
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# [Text(0.5, 0, 'Rating for the products'),
#  Text(0.5, 1.0, 'Amazon Product Distribution')]

# %%
#plt.hist(ratings1['ratings'],bins= 10)
plt.hist(ratings1['ratings'],bins= 10)
plt.gca().set(title = 'Amazon Product Distribution',xlabel = 'Rating for the products')
# Out:
# [Text(0.5, 0, 'Rating for the products'),
#  Text(0.5, 1.0, 'Amazon Product Distribution')]

# %%
fig=plt.figure(figsize=(8, 5))
ratings1['ratings'].value_counts().plot.bar()

# %%
ratings1.userId.value_counts()
# Out:
# A5JLAU2ARJ0BO            520
# ADLVFFE4VBT8             501
# A3OXHLG6DIBRW8           498
# A6FIAB28IS79             431
# A680RUE1FDO8B            406
# A1ODOGXEYECQQ8           380
# A36K2N527TXXJN           314
# A2AY4YUOX2N1BQ           311
# AWPODHOB4GFWL            308
# A25C2M3QF9G7OQ           296
# ARBKYIVNYWK3C            296
# A22CW0ZHY3NJH8           292
# A3EXWV8FNSSFL6           282
# A38RMU1Y5TDP9            282
# A3LGT6UZL99IW1           279
# A2NOW4U7W3F7RI           277
# A23GFTVIETX7DS           270
# A3PD8JD9L4WEII           266
# A17BUUBOU0598B           261
# A3AYSYSLHU26U9           257
# A2XRMQA6PJ5ZJ8           253
# A231WM2Z2JL0U3           252
# A12DQZKRKTNF5E           252
# A1UQBFCERIP7VJ           247
# AGVWTYW0ULXHT            244
# A203OCQQ12MAVT           240
# AEJAGHLC675A7            239
# A2NYK9KWFMJV4Y           238
# A3A4ZAIBQWKOZS           236
# A31N0XY2UTB25C           227
#                         ...
# A3AAWVOC7Z0BM4             1
# ...

# %%
# if ratings1.userId.value_counts() > 50:
#     print(ratings1.userId)

# %%
# find the total number of unique users. 
print("The total number of unique users: ", len(ratings1["userId"].unique()))


#  4201696 - Unique users available 
#  7824482 - Total users available
# Out:
# The total number of unique users:  4201696

# %%
# Creating the subset

creating_subset_series= ratings1.userId.value_counts()

# %%
creating_subset_series1 = creating_subset_series.to_frame()

# %%
creating_subset_series1
# Out:
#                        userId
# A5JLAU2ARJ0BO             520
# ADLVFFE4VBT8              501
# A3OXHLG6DIBRW8            498
# A6FIAB28IS79              431
# A680RUE1FDO8B             406
# A1ODOGXEYECQQ8            380
# A36K2N527TXXJN            314
# A2AY4YUOX2N1BQ            311
# AWPODHOB4GFWL             308
# A25C2M3QF9G7OQ            296
# ARBKYIVNYWK3C             296
# A22CW0ZHY3NJH8            292
# A3EXWV8FNSSFL6            282
# A38RMU1Y5TDP9             282
# A3LGT6UZL99IW1            279
# A2NOW4U7W3F7RI            277
# A23GFTVIETX7DS            270
# A3PD8JD9L4WEII            266
# A17BUUBOU0598B            261
# A3AYSYSLHU26U9            257
# A2XRMQA6PJ5ZJ8            253
# A231WM2Z2JL0U3            252
# A12DQZKRKTNF5E            252
# A1UQBFCERIP7VJ            247
# AGVWTYW0ULXHT             244
# A203OCQQ12MAVT            240
# AEJAGHLC675A7             239
# A2NYK9KWFMJV4Y            238
# A3A4ZAIBQWKOZS            236
# A31N0XY2UTB25C            227
# ...

# %%
ratings_subset_50=creating_subset_series1[creating_subset_series1['userId'] > 50 ]
ratings_subset_50
# Out:
#                 userId
# A5JLAU2ARJ0BO      520
# ADLVFFE4VBT8       501
# A3OXHLG6DIBRW8     498
# A6FIAB28IS79       431
# A680RUE1FDO8B      406
# A1ODOGXEYECQQ8     380
# A36K2N527TXXJN     314
# A2AY4YUOX2N1BQ     311
# AWPODHOB4GFWL      308
# A25C2M3QF9G7OQ     296
# ARBKYIVNYWK3C      296
# A22CW0ZHY3NJH8     292
# A3EXWV8FNSSFL6     282
# A38RMU1Y5TDP9      282
# A3LGT6UZL99IW1     279
# A2NOW4U7W3F7RI     277
# A23GFTVIETX7DS     270
# A3PD8JD9L4WEII     266
# A17BUUBOU0598B     261
# A3AYSYSLHU26U9     257
# A2XRMQA6PJ5ZJ8     253
# A231WM2Z2JL0U3     252
# A12DQZKRKTNF5E     252
# A1UQBFCERIP7VJ     247
# AGVWTYW0ULXHT      244
# A203OCQQ12MAVT     240
# AEJAGHLC675A7      239
# A2NYK9KWFMJV4Y     238
# A3A4ZAIBQWKOZS     236
# A31N0XY2UTB25C     227
# ...                ...
# A1AKW788238PWQ      51
# AKCZIJ6ZHE41D       51
# A3AGQAXTX6VRJ3      51
# A185O1MX1RP964      51
# A1BXVZSQOJE6UE      51
# A32AK8FOAZEPE2      51
# A328GLDSDNFYII      51
# AFM2J3HJNPIHV       51
# ...

# %%
ratings_subset_50_index = ratings_subset_50.index

# %%
ratings_subset_50_index
# Out:
# CategoricalIndex(['A5JLAU2ARJ0BO', 'ADLVFFE4VBT8', 'A3OXHLG6DIBRW8',
#                   'A6FIAB28IS79', 'A680RUE1FDO8B', 'A1ODOGXEYECQQ8',
#                   'A36K2N527TXXJN', 'A2AY4YUOX2N1BQ', 'AWPODHOB4GFWL',
#                   'A25C2M3QF9G7OQ',
#                   ...
#                   'A2LF07KCXDR70D', 'A1XK4VP74IB9TQ', 'A1FMU4CJLIDHR9',
#                   'A3MV1KKHX51FYT', 'ANTGGAQYPSWHF', 'ASF3J4UYV34KA',
#                   'A3M82NO6OU1FHS', 'A3M7R4PD0FEPUB', 'A1VLE2SH9J8WYS',
#                   'A1AZQCVCDBQP6'],
#                  categories=['A00000262KYZUE4J55XGL', 'A000063614T1OE0BUSKUT', 'A00009182QVLSWIGHLS1B', 'A00009661LC9LQPGKJ24G', 'A00010809P09NUU6ZP6H', 'A00014061C2IZNE0YEILY', 'A000145014WOTZJ5NSKOR', 'A00015222LZ55IJSVL5IX', ...], ordered=False, dtype='category', length=1466)

# %%
ratings_subset_50_index.shape
# Out:
# (1466,)

# %%
new_dataset1 = ratings1[ratings1['userId'].isin (ratings_subset_50.index)]

# %%
new_dataset1
# Out:
#                  userId   productId  ratings
# 118       AT09WGFUM934H  0594481813      3.0
# 177      A32HSNCNPRUMTR  0970407998      1.0
# 178      A17HMM1M7T9PJ1  0970407998      4.0
# 492      A3CLWR1UUZT6TG  0972683275      5.0
# 631      A3TAS1AG6FMBQW  0972683275      5.0
# 1138     A25RTRAPQAJBDJ  0972683275      5.0
# 1310     A3LDPF5FMB782Z  1400501466      5.0
# 1322     A1A5KUIIIHFF4U  1400501466      1.0
# 1335     A2XIOXRRYX0KZY  1400501466      3.0
# 1451      AW3LX47IHPFRL  1400501466      5.0
# 1456     A1E3OB6QMBKRYZ  1400501466      1.0
# 1588     A3LDPF5FMB782Z  1400501520      5.0
# 1696     A3LDPF5FMB782Z  1400501776      5.0
# 1777     A18S2VGUH9SCV5  1400501776      4.0
# 1987     A1K4G5YJDJQI6Q  1400532620      1.0
# 1990     A1PPS91NLI7KEH  1400532620      5.0
# 2082     A2ZR3YTMEEIIZ4  1400532655      5.0
# 2150     A3CLWR1UUZT6TG  1400532655      5.0
# 2162      A5JLAU2ARJ0BO  1400532655      1.0
# 2228     A1P4XD7IORSEFN  1400532655      4.0
# ...

# %%
from surprise import Dataset,Reader
from surprise.model_selection import train_test_split
from surprise import KNNWithMeans
from surprise import accuracy

data = Dataset.load_from_df(new_dataset1, reader,)
reader = Reader(rating_scale=(1, 5))
trainset, testset = train_test_split(data, test_size=0.30,random_state=5)

# %%
data

# %%
algo = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': True})
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
type(trainset)
# Out:
# surprise.trainset.Trainset

# %%
test_pred = algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='A3M82NO6OU1FHS', iid='B0094NXBZ0', r_ui=4.0, est=4.243243243243243, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ASCBJEPXTOU0V', iid='B003DA4D2U', r_ui=5.0, est=4.261637764707258, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3O1FVLUD9X1XC', iid='B001NJ0D0Y', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3QU3O79AGNWCY', iid='B000HDJT4S', r_ui=5.0, est=4.4, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A23NSKTMSPPBTR', iid='B004CLYEFK', r_ui=4.0, est=4.052104598638871, details={'actual_k': 17, 'was_impossible': False}),
#  Prediction(uid='A3639Z6O5JBLIZ', iid='B004I3VZJK', r_ui=5.0, est=4.702127659574468, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3NG7X4APIV649', iid='B004RE20EO', r_ui=5.0, est=4.261637764707258, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
# ...

# %%
# Similar products


sim_products_user = algo.get_neighbors(trainset.to_inner_uid("A1T9MILRRZ00F8"),10)
[trainset.to_raw_uid(x) for x in sim_products_user]
# Out:
# ['A1JZFGZEZVWQPY',
#  'A1KDUQ2HU0WD68',
#  'A1RL1OTV8IJMVD',
#  'A3QNQQKJTL76H0',
#  'A2BMZRO0H7TFCS',
#  'A2RW587355CMVA',
#  'AR3EVUQF0AC7R',
#  'AL5CUWBFBMWYQ',
#  'ASJLXOX1VD4DF',
#  'A1GW7V6S6XSXX3']

# %%
sim_products_item = algo.get_neighbors(trainset.to_inner_iid("B004T9RR6I"),10)
[trainset.to_raw_iid(x) for x in sim_products_user]
# Out:
# ['B003YD1MMU',
#  'B00D2LR76E',
#  'B004H6L5EI',
#  'B006W8U2MU',
#  'B006RJQ74G',
#  'B003WGJYCY',
#  'B004WK3U9W',
#  'B00CG0JCEC',
#  'B0082E9K7U',
#  'B002NFW4XG']

# %%
# RMSE Estimation

print("RMSE Estimation : Test Set ")
accuracy.rmse(test_pred)
# Out:
# RMSE Estimation : Test Set
# RMSE: 1.0542
# 1.0541922641326023

# %%
 #   Top 5 Product Recommendation
    
testset1 = trainset.build_anti_testset()

# %%
testset1[0:5]
# Out:
# [('A31N0XY2UTB25C', 'B004C9P9TM', 4.261637764707258),
#  ('A31N0XY2UTB25C', 'B003V2QIGY', 4.261637764707258),
#  ('A31N0XY2UTB25C', 'B0088PPFP4', 4.261637764707258),
#  ('A31N0XY2UTB25C', 'B00FQQ4PNQ', 4.261637764707258),
#  ('A31N0XY2UTB25C', 'B003CP0K96', 4.261637764707258)]

# %%
len(testset1)
# Out:
# 54694503

# %%
predict1 = algo.test(testset1[0:10000])
[[x.uid,x.est] for x in predict1]
# Out:
# [['A31N0XY2UTB25C', 4.8725858246391],
#  ['A31N0XY2UTB25C', 4.732484076433121],
#  ['A31N0XY2UTB25C', 5],
#  ['A31N0XY2UTB25C', 4.037505652500127],
#  ['A31N0XY2UTB25C', 4.732484076433121],
#  ['A31N0XY2UTB25C', 4.768847712796757],
#  ['A31N0XY2UTB25C', 4.732484076433121],
#  ['A31N0XY2UTB25C', 4.537362125213608],
#  ['A31N0XY2UTB25C', 4.732484076433121],
#  ['A31N0XY2UTB25C', 4.732484076433121],
#  ['A31N0XY2UTB25C', 4.564385767027102],
#  ['A31N0XY2UTB25C', 5],
#  ['A31N0XY2UTB25C', 4.732484076433121],
#  ['A31N0XY2UTB25C', 4.732484076433121],
#  ['A31N0XY2UTB25C', 4.732484076433121],
#  ['A31N0XY2UTB25C', 4.455083160271994],
#  ['A31N0XY2UTB25C', 4.732484076433121],
#  ['A31N0XY2UTB25C', 4.930447053240128],
#  ['A31N0XY2UTB25C', 4.732484076433121],
#  ['A31N0XY2UTB25C', 4.732484076433121],
#  ['A31N0XY2UTB25C', 4.503912959448044],
#  ['A31N0XY2UTB25C', 5],
#  ['A31N0XY2UTB25C', 4.732484076433121],
#  ['A31N0XY2UTB25C', 4.732484076433121],
#  ['A31N0XY2UTB25C', 3.47515232845132],
# ...

# %%
predict1_dataframe = pd.DataFrame([[x.uid,x.est] for x in predict1])
predict1_dataframe.columns = ["userId","est_rating"]
predict1_dataframe.sort_values(by = ["userId", "est_rating"],ascending=False,inplace=True)
predict1_dataframe.head(20)
# Out:
#              userId  est_rating
# 2    A31N0XY2UTB25C         5.0
# 11   A31N0XY2UTB25C         5.0
# 21   A31N0XY2UTB25C         5.0
# 36   A31N0XY2UTB25C         5.0
# 37   A31N0XY2UTB25C         5.0
# 40   A31N0XY2UTB25C         5.0
# 45   A31N0XY2UTB25C         5.0
# 55   A31N0XY2UTB25C         5.0
# 56   A31N0XY2UTB25C         5.0
# 63   A31N0XY2UTB25C         5.0
# 75   A31N0XY2UTB25C         5.0
# 87   A31N0XY2UTB25C         5.0
# 88   A31N0XY2UTB25C         5.0
# 89   A31N0XY2UTB25C         5.0
# 95   A31N0XY2UTB25C         5.0
# 96   A31N0XY2UTB25C         5.0
# 102  A31N0XY2UTB25C         5.0
# 103  A31N0XY2UTB25C         5.0
# 104  A31N0XY2UTB25C         5.0
# 105  A31N0XY2UTB25C         5.0
