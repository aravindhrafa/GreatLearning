# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1st Question

# %%
a1=pd.read_csv("D:\\GL\\statistics_learning_test\\test_files\\Laliga.csv",header=1)
print(a1)
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1          Real Madrid       86   4385        2762     1647        552
# 1     2            Barcelona       86   4262        2762     1581        573
# 2     3      Atletico Madrid       80   3442        2614     1241        598
# 3     4             Valencia       82   3386        2664     1187        616
# 4     5      Athletic Bilbao       86   3368        2762     1209        633
# 5     6              Sevilla       73   2819        2408      990        531
# 6     7             Espanyol       82   2792        2626      948        608
# 7     8        Real Sociedad       70   2573        2302      864        577
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# ...

# %%
replacement=a1.replace('-',0)
print(replacement)
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1          Real Madrid       86   4385        2762     1647        552
# 1     2            Barcelona       86   4262        2762     1581        573
# 2     3      Atletico Madrid       80   3442        2614     1241        598
# 3     4             Valencia       82   3386        2664     1187        616
# 4     5      Athletic Bilbao       86   3368        2762     1209        633
# 5     6              Sevilla       73   2819        2408      990        531
# 6     7             Espanyol       82   2792        2626      948        608
# 7     8        Real Sociedad       70   2573        2302      864        577
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# ...

# %% [markdown]
# # 2nd Question

# %%
#read_data1['Debut'].truncate(before=10,after= 30)
countries_under_1980s =a1['Team'].loc[(a1['Debut'] > '1930') & (a1['Debut'] < '1980')]
print(countries_under_1980s)
# Countris started their career between 1930 to 1980
#print(type(countries_under_1980s))   Ans: Series
# Out:
# 3                Valencia
# 5                 Sevilla
# 8                Zaragoza
# 9              Real Betis
# 10    Deportivo La Coruna
# 11             Celta Vigo
# 12             Valladolid
# 14         Sporting Gijon
# 15                Osasuna
# 16                 Malaga
# 17                 Oviedo
# 18               Mallorca
# 19             Las Palmas
# 21                Granada
# 22         Rayo Vallecano
# 23                  Elche
# 25               Hercules
# 26               Tenerife
# 27                 Murcia
# 28                 Alaves
# 29                Levante
# 30              Salamanca
# 31               Sabadell
# 32                  Cadiz
# 34              Castellon
# 37                Cordoba
# 39             Recreativo
# 40              Burgos CF
# 41             Pontevedra
# 46              Gimnastic
# 49               Alcoyano
# 50                   Jaen
# 52             AD Almeria
# 54                 Lleida
# 57                 Condal
# ...

# %%
replacement['Points']=replacement['Points'].apply(pd.to_numeric)
#print(type(replacement['Points']))

# Previously the datatype of the points is 'object', so conversion is bit tough
# So conversion from object to int64 is performed through the above code

# %% [markdown]
# # 3rd Question

# %%
#     3) Question
replacement.sort_values(by=['Points'],ascending= False)
replacement['Team'].head(5)
# Out:
# 0        Real Madrid
# 1          Barcelona
# 2    Atletico Madrid
# 3           Valencia
# 4    Athletic Bilbao
# Name: Team, dtype: object

# %%
replacement['GamesWon']=replacement['GamesWon'].apply(pd.to_numeric)  # Object to numeric conversion

# %%
replacement['GamesPlayed']=replacement['GamesPlayed'].apply(pd.to_numeric) # Object to numeric conversion

# %% [markdown]
# # 5th question

# %%
#              5) Question
replacement['WinningPercent']=(replacement['GamesWon']/replacement['GamesPlayed'])*100

#creation of GamePlayed column and performing the mathematical calculations

# %%
print(replacement)
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86    4385         2762      1647
# 1     2            Barcelona       86    4262         2762      1581
# 2     3      Atletico Madrid       80    3442         2614      1241
# 3     4             Valencia       82    3386         2664      1187
# 4     5      Athletic Bilbao       86    3368         2762      1209
# 5     6              Sevilla       73    2819         2408       990
# 6     7             Espanyol       82    2792         2626       948
# 7     8        Real Sociedad       70    2573         2302       864
# 8     9             Zaragoza       58    2109         1986       698
# 9    10           Real Betis       51    1884         1728       606
# 10   11  Deportivo La Coruna       45    1814         1530       563
# 11   12           Celta Vigo       51    1789         1698       586
# 12   13           Valladolid       42    1471         1466       463
# ...

# %%
replacement.fillna(0)  # Conversion from NaN  to 0 value
# Out:
#     88                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0    1          Real Madrid       86    4385         2762      1647
# 1    2            Barcelona       86    4262         2762      1581
# 2    3      Atletico Madrid       80    3442         2614      1241
# 3    4             Valencia       82    3386         2664      1187
# 4    5      Athletic Bilbao       86    3368         2762      1209
# 5    6              Sevilla       73    2819         2408       990
# 6    7             Espanyol       82    2792         2626       948
# 7    8        Real Sociedad       70    2573         2302       864
# 8    9             Zaragoza       58    2109         1986       698
# 9   10           Real Betis       51    1884         1728       606
# 10  11  Deportivo La Coruna       45    1814         1530       563
# 11  12           Celta Vigo       51    1789         1698       586
# 12  13           Valladolid       42    1471         1466       463
# ...

# %%
replacement.sort_values(by=['WinningPercent'],ascending=False)
replacement['Team'].head(5)
# Out:
# 0        Real Madrid
# 1          Barcelona
# 2    Atletico Madrid
# 3           Valencia
# 4    Athletic Bilbao
# Name: Team, dtype: object

# %% [markdown]
# # 6th Question

# %%
replacement.groupby(['BestPosition'])['Points'].sum()
# Out:
# BestPosition
# 1     27933
# 2      6904
# 3      5221
# 4      6563
# 5      1884
# 6      2113
# 7      1186
# 8      1134
# 9        96
# 10      450
# 11      445
# 12      511
# 14       71
# 15       14
# 16       81
# 17      266
# 19       81
# 20       34
# Name: Points, dtype: int64

# %% [markdown]
# # 5th Question

# %%
#
replacement['GoalsFor']=replacement['GoalsFor'].apply(pd.to_numeric)
replacement['GoalsAgainst']=replacement['GoalsAgainst'].apply(pd.to_numeric)

# %%
def Goal_diff_count():
    replacement['Goal_diff_count'] = replacement['GoalsFor'] - replacement['GoalsAgainst']
    return replacement['Goal_diff_count']

# %%
replacement.apply(Goal_diff_count)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-179-6c4d422e0f54> in <module>
# ----> 1 replacement.apply(Goal_diff_count)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
# ...
